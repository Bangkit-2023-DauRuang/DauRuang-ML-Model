# %%
import os
import tensorflow as tf
from tensorflow.keras.utils import load_img, img_to_array
from PIL import Image
import numpy as np

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
#load model
model = tf.keras.models.load_model('./saved_model/93% accuracy (Kaleng, Kertas, Minyak dan Organik)')

# %%
test_img = "./test"

class_names = ["kaleng","kertas","minyak","organik"]

test=[]

for fn in os.listdir(test_img):
 
  # predicting images
  path = os.path.join(test_img,fn)
  img = load_img(path, target_size=(225, 225))
  x = img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images)
  print(fn)
  print( classes)
  print("Prediction : " + class_names[np.argmax(classes)] + "\n")
# Out:
# 1/1 [==============================] - 0s 36ms/step
# gunting.jpg
# [[9.9994421e-01 5.7874170e-36 5.5842203e-05 0.0000000e+00]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 29ms/step
# Image_1.jpg
# [[9.9999928e-01 7.2005531e-07 4.4701992e-13 6.6910765e-31]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 26ms/step
# kaleng01.jpg
# [[1.0000000e+00 0.0000000e+00 4.2932946e-22 0.0000000e+00]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 35ms/step
# kaleng02.jpg
# [[1.0000000e+00 0.0000000e+00 0.0000000e+00 3.6555735e-38]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 31ms/step
# kaleng03.jpg
# [[1.0000000e+00 0.0000000e+00 2.0808604e-28 0.0000000e+00]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 27ms/step
# kaleng04.jpg
# [[1.000000e+00 0.000000e+00 7.637883e-35 0.000000e+00]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 31ms/step
# kaleng05.jpg
# [[1.0000000e+00 0.0000000e+00 3.5333257e-11 0.0000000e+00]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 36ms/step
# kaleng06.jpg
# [[1. 0. 0. 0.]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 29ms/step
# kaleng07.jpg
# [[1. 0. 0. 0.]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 28ms/step
# kaleng08.jpg
# [[1. 0. 0. 0.]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 27ms/step
# kaleng09.jpg
# [[1. 0. 0. 0.]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 29ms/step
# kertas01.jpg
# [[3.2652445e-37 1.0000000e+00 6.9733763e-32 0.0000000e+00]]
# Prediction : kertas
#
# 1/1 [==============================] - 0s 29ms/step
# kertas02.jpg
# [[3.1097221e-07 9.9974078e-01 2.5880898e-04 1.5706566e-35]]
# Prediction : kertas
#
# 1/1 [==============================] - 0s 26ms/step
# kertas03.jpg
# [[6.6468306e-03 9.9335313e-01 5.8499479e-15 8.8343223e-24]]
# Prediction : kertas
#
# 1/1 [==============================] - 0s 29ms/step
# kertas04.jpg
# [[4.3315862e-32 1.0000000e+00 2.4702078e-27 3.4365072e-29]]
# Prediction : kertas
#
# 1/1 [==============================] - 0s 26ms/step
# kertas05.jpg
# [[1.0000000e+00 1.5941089e-25 2.0337685e-11 8.1962425e-30]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 29ms/step
# kertas06.jpg
# [[1.3363975e-16 1.0000000e+00 1.3700487e-22 2.0822197e-34]]
# Prediction : kertas
#
# 1/1 [==============================] - 0s 31ms/step
# minyak_138.jpg
# [[0.1493888  0.         0.85061115 0.        ]]
# Prediction : minyak
#
# 1/1 [==============================] - 0s 26ms/step
# minyak_139.jpg
# [[1.4947128e-18 0.0000000e+00 1.0000000e+00 0.0000000e+00]]
# Prediction : minyak
#
# 1/1 [==============================] - 0s 26ms/step
# minyak_140.jpg
# [[3.5904172e-12 0.0000000e+00 1.0000000e+00 0.0000000e+00]]
# Prediction : minyak
#
# 1/1 [==============================] - 0s 27ms/step
# minyak_145.jpg
# [[1.080575e-12 0.000000e+00 1.000000e+00 0.000000e+00]]
# Prediction : minyak
#
# 1/1 [==============================] - 0s 27ms/step
# minyak_146.jpg
# [[3.983935e-09 0.000000e+00 1.000000e+00 0.000000e+00]]
# Prediction : minyak
#
# 1/1 [==============================] - 0s 27ms/step
# minyak_147.jpg
# [[0. 0. 1. 0.]]
# Prediction : minyak
#
# 1/1 [==============================] - 0s 28ms/step
# organik01.jpg
# [[1.000000e+00 0.000000e+00 1.643434e-30 0.000000e+00]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 28ms/step
# organik02.jpg
# [[0. 0. 0. 1.]]
# Prediction : organik
#
# 1/1 [==============================] - 0s 32ms/step
# organik03.jpg
# [[0. 0. 0. 1.]]
# Prediction : organik
#
# 1/1 [==============================] - 0s 28ms/step
# organik04.jpg
# [[0.000000e+00 0.000000e+00 4.050192e-25 1.000000e+00]]
# Prediction : organik
#
# 1/1 [==============================] - 0s 27ms/step
# organik05.jpg
# [[1.0000000e+00 0.0000000e+00 0.0000000e+00 1.2442413e-13]]
# Prediction : kaleng
#
# 1/1 [==============================] - 0s 25ms/step
# organik06.jpg
# [[4.6350285e-29 3.9966291e-32 1.0000000e+00 0.0000000e+00]]
# Prediction : minyak
#
# 1/1 [==============================] - 0s 29ms/step
# organik07.jpg
# [[0. 0. 0. 1.]]
# Prediction : organik
#
# 1/1 [==============================] - 0s 26ms/step
# organik08.jpg
# [[0.0000000e+00 0.0000000e+00 2.2685083e-37 1.0000000e+00]]
# Prediction : organik
#
# 1/1 [==============================] - 0s 26ms/step
# WhatsApp Image 2023-06-02 at 14.45.35.jpg
# [[0. 1. 0. 0.]]
# Prediction : kertas
